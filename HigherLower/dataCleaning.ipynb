# %%
import pandas as pd

# %%
df = pd.read_csv ('data.csv')

# %%
df
# Out:
#      rank                name channel_Info                  Category  Posts  \
# 0       1           instagram        brand               photography   7.3K
# 1       2           cristiano         male  Health, Sports & Fitness   3.4K
# 2       3            leomessi         male  Health, Sports & Fitness     1K
# 3       4         kyliejenner       female             entertainment     7K
# 4       5         selenagomez       female             entertainment   1.8K
# ..    ...                 ...          ...                       ...    ...
# 195   196            fcbayern         male  Health, Sports & Fitness  16.8K
# 196   197         colesprouse         male             entertainment   1.1K
# 197   198        shaymitchell         male             entertainment   6.3K
# 198   199        ivetesangalo       female             entertainment   7.8K
# 199   200  paollaoliveirareal       female             entertainment   4.8K
#
#     Followers Avg. Likes Eng Rate
# ...

# %%
df_dropped=df.drop(['rank','channel_Info','Category','Posts','Avg. Likes','Eng Rate'],axis = 1)
df_dropped
# Out:
#                    name Followers
# 0             instagram    580.1M
# 1             cristiano    519.9M
# 2              leomessi    403.7M
# 3           kyliejenner    375.9M
# 4           selenagomez    365.3M
# ..                  ...       ...
# 195            fcbayern     35.4M
# 196         colesprouse     35.3M
# 197        shaymitchell     35.1M
# 198        ivetesangalo       35M
# 199  paollaoliveirareal     34.9M
#
# [200 rows x 2 columns]

# %%
filename = 'instaFollowers'
df_dropped.to_csv(filename, sep=',', index=False, encoding='utf-8')

# %%
 d = pd.read_csv("instaFollowers.txt", delimiter=" ", header = None).to_dict()[0]

# %%
d
# Out:
# {0: 'name,Followers',
#  1: 'instagram,580.1M',
#  2: 'cristiano,519.9M',
#  3: 'leomessi,403.7M',
#  4: 'kyliejenner,375.9M',
#  5: 'selenagomez,365.3M',
#  6: 'therock,354.3M',
#  7: 'arianagrande,345.6M',
#  8: 'kimkardashian,336.3M',
#  9: 'beyonce,287.3M',
#  10: 'khloekardashian,283.9M',
#  11: 'justinbieber,270.2M',
#  12: 'nike,257.6M',
#  13: 'taylorswift,236.2M',
#  14: 'jlo,228.8M',
#  15: 'virat.kohli,228M',
#  16: 'kendalljenner,223.4M',
#  17: 'natgeo,220.6M',
#  18: 'nickiminaj,206.8M',
#  19: 'kourtneykardash,206.2M',
#  20: 'kendalljenner,204.4M',
#  21: 'neymarjr,196.2M',
#  22: 'natgeo,196.1M',
#  23: 'mileycyrus,189.9M',
#  24: 'katyperry,179.8M',
#  25: 'zendaya,161.8M',
#  26: 'kevinhart4real,157.6M',
#  27: 'iamcardib,145.6M',
#  28: 'ddlovato,143.5M',
#  29: 'badgalriri,139.2M',
#  30: 'kingjames,139.2M',
#  31: 'champagnepapi,127.6M',
#  32: 'theellenshow,127.1M',
#  33: 'chrisbrownofficial,125.5M',
#  34: 'realmadrid,120.9M',
#  35: 'fcbarcelona,113.6M',
# ...
